# %% [markdown]
# ## Working with JSON

# %%
import pandas as pd

# %%
df = pd.read_json("train.json")
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
df = df.drop(columns='id')
# df.drop(columns='id',inplace=True)

# %%
df
# Out:
#            cuisine                                        ingredients
# 0            greek  [romaine lettuce, black olives, grape tomatoes...
# 1      southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2         filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3           indian                [water, vegetable oil, wheat, salt]
# 4           indian  [black pepper, shallots, cornflour, cayenne pe...
# ...            ...                                                ...
# 39769        irish  [light brown sugar, granulated sugar, butter, ...
# 39770      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772      chinese  [boneless chicken skinless thigh, minced garli...
# 39773      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 2 columns]

# %% [markdown]
# ## Url dataset

# %%
df_url = pd.read_json("https://api.github.com/users/hadley/orgs")
df_url
# Out:
#                login        id                           node_id  \
# 0              ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1            rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2             rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 3           ropensci   1200269  MDEyOk9yZ2FuaXphdGlvbjEyMDAyNjk=
# 4           rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 5              r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 6        RConsortium  15366137  MDEyOk9yZ2FuaXphdGlvbjE1MzY2MTM3
# 7          tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
# 8              r-lib  22618716  MDEyOk9yZ2FuaXphdGlvbjIyNjE4NzE2
# 9  rstudio-education  34165516  MDEyOk9yZ2FuaXphdGlvbjM0MTY1NTE2
#
#                                              url  \
# 0              https://api.github.com/orgs/ggobi
# 1            https://api.github.com/orgs/rstudio
# 2             https://api.github.com/orgs/rstats
# 3           https://api.github.com/orgs/ropensci
# ...

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/11.9 MB 5.1 MB/s eta 0:00:03
#      ------ --------------------------------- 1.8/11.9 MB 5.2 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.1/11.9 MB 5.6 MB/s eta 0:00:02
#      -------------- ------------------------- 4.2/11.9 MB 5.6 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.2/11.9 MB 5.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 6.6/11.9 MB 5.6 MB/s eta 0:00:01
#      -------------------------- ------------- 7.9/11.9 MB 5.6 MB/s eta 0:00:01
#      ------------------------------ --------- 8.9/11.9 MB 5.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.0/11.9 MB 5.5 MB/s eta 0:00:01
#      ------------------------------------- -- 11.0/11.9 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------------  11.8/11.9 MB 5.3 MB/s eta 0:00:01
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = "localhost", user = 'root', password = '', database = 'world')

# %%
pd.read_sql_query("Select * FROM city where district LIKE 'kabol'",conn)
# Out:
# C:\Users\Garv\AppData\Local\Temp\ipykernel_9484\2507134745.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("Select * FROM city where District LIKE 'kabol'",conn)
#    ID   Name CountryCode District  Population
# 0   1  Kabul         AFG    Kabol     1780000

# %%
pd.read_sql_query("SELECT * FROM countrylanguage WHERE Language = 'English' AND Percentage > 10",conn)
# Out:
# C:\Users\Garv\AppData\Local\Temp\ipykernel_9484\1386989798.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM countrylanguage WHERE Language = 'English' AND Percentage > 10",conn)
#    CountryCode Language IsOfficial  Percentage
# 0          AUS  English          T        81.2
# 1          BLZ  English          T        50.8
# 2          BMU  English          T       100.0
# 3          CAN  English          T        60.4
# 4          GBR  English          T        97.3
# 5          GIB  English          T        88.9
# 6          GUM  English          T        37.5
# 7          IRL  English          T        98.4
# 8          LCA  English          T        20.0
# 9          NZL  English          T        87.0
# 10         PRI  English          F        47.4
# ...
